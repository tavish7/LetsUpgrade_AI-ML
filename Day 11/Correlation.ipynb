# %%
import pandas as pd
from scipy.stats import pearsonr

# %%
df = pd.read_csv('general_data.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df['Attrition'].replace(to_replace=('No','Yes'),value=(0,1), inplace=True)
df['Gender'].replace(to_replace=('Male','Female'),value=(0,1), inplace=True)
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0       1  ...                 1.0      Y                11              8
# ...

# %%
# 1. Correlation between Attrition and Age
# Ho : There is no significance difference between Attrition and Age

stats,p = pearsonr(df.Attrition,df.Age)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  -0.15920500686577965  P-value :  1.996801615886744e-26
# Reject Null Hypothesis
# Negative Correlation

# %%
# 2. Correlation between Attrition and Gender
# Ho : There is no significance difference between Attrition and Gender

stats,p = pearsonr(df.Attrition,df.Gender)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  -0.01812507887701024  P-value :  0.22881970951795952
# Accept Null Hypothesis
# Negative Correlation

# %%
# 3. Correlation between Attrition and DistanceFromHome
# Ho : There is no significance difference between Attrition and DistanceFromHome

stats,p = pearsonr(df.Attrition,df.DistanceFromHome)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  -0.00973014101017966  P-value :  0.5182860428050771
# Accept Null Hypothesis
# Negative Correlation

# %%
# 4. Correlation between Attrition and Education
# Ho : There is no significance difference between Attrition and Education

stats,p = pearsonr(df.Attrition,df.Education)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  -0.015111167710968711  P-value :  0.3157293177118575
# Accept Null Hypothesis
# Negative Correlation

# %%
# 5. Correlation between Attrition and PercentSalaryHike
# Ho : There is no significance difference between Attrition and PercentSalaryHike

stats,p = pearsonr(df.Attrition,df.PercentSalaryHike)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  0.03253259489105351  P-value :  0.030743386433355353
# Reject Null Hypothesis
# Positive Correlation

# %%
# 6. Correlation between Attrition and StockOptionLevel
# Ho : There is no significance difference between Attrition and StockOptionLevel

stats,p = pearsonr(df.Attrition,df.StockOptionLevel)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  -0.006838852403261521  P-value :  0.6498072937475723
# Accept Null Hypothesis
# Negative Correlation

# %%
# 7. Correlation between Attrition and TrainingTimesLastYear
# Ho : There is no significance difference between Attrition and TrainingTimesLastYear

stats,p = pearsonr(df.Attrition,df.TrainingTimesLastYear)
print("Correlation : ",stats," P-value : ",p)
if p>=0.05:
    print("Accept Null Hypothesis")
elif p<0.05:
    print("Reject Null Hypothesis")
if stats>0:
    print("Positive Correlation")
elif stats<0:
    print("Negative Correlation")
# Out:
# Correlation :  -0.04943057624425501  P-value :  0.0010247061915362814
# Reject Null Hypothesis
# Negative Correlation

# %%
df.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# Gender                   0.039352  -0.018125          0.044173   0.016547
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# ...
